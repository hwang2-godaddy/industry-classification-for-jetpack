# %%
import pandas as pd

# %%
df_tree = pd.read_csv("df_tree_export_categories_parents.csv", header=0)
df_tree.head()
# Out:
#                        tree   group                  name           parent
# 0             Active Living  sports         Active Living              NaN  \
# 1                   Archery  sports               Archery           active
# 2      Archery and Shooting  sports  Archery and Shooting           active
# 3                  Gun Club    guns              Gun Club  archeryshooting
# 4                   Bowling   hobby               Bowling           active
#
#                          parents_path               id
# 0                                 NaN           active  \
# 1                       Active Living          archery
# 2                       Active Living  archeryshooting
# 3  Active Living/Archery and Shooting          gunclub
# 4                       Active Living          bowling
#
#                                               photos  visible
# 0  ['101641' '101642' '101643' '101660' '103620' ...     True  \
# ...

# %%
df_tree['id'].value_counts()
# Out:
# id
# active                         1
# womenshealthclinic             1
# physicians                     1
# physicalfitnessprogram         1
# physicaltherapy                1
#                               ..
# maker                          1
# mailboxsupplier                1
# snowremoval                    1
# shoerepair                     1
# waterworksequipmentsupplier    1
# Name: count, Length: 1637, dtype: int64

# %%
list_1637 = set(df_tree['id'].values)
len(list_1637)
# Out:
# 1637

# %%
# Query 1

# with temp_data as
# (
# select
#     B.domain_name,
#     A.website_id,
#     A.business_category,
#     B.gd_domain
# from gmode.gocentral_websitebuilder_session A
# join gmode.gocentral_website_history B
# on A.website_id = B.website_id
# where A.business_category not like '%_other_%'
#       and B.gd_domain = 0
# )
# select distinct business_category
# from temp_data
# where business_category not like ''
# order by 1

# %%
df_query1 = pd.read_csv("query1_results.csv", header=0)
df_query1.head()
# Out:
#                 business_category
# 0                      3dservices
# 1                abortionservices
# 2         abuseaddictiontreatment
# 3                     accessories
# 4  accidentpropertydamageattorney

# %%
df_query1['business_category'].value_counts()
# Out:
# business_category
# 3dservices                    1
# outdoorfurnituredcorstores    1
# parochialschool               1
# parksrecreation               1
# parks                         1
#                              ..
# farmersmarket                 1
# farmequipmentsupplies         1
# farmequipmentdealers          1
# farmbureau                    1
# zoos                          1
# Name: count, Length: 1683, dtype: int64

# %%
list_1684 = set(df_query1['business_category'].values)
len(list_1684)
# Out:
# 1683

# %%
print(len(list_1637 - list_1684))
print(len(list_1684 - list_1637))

print(len(list_1684 & list_1637))
# Out:
# 3
# 49
# 1634

# %%
business_category_to_be_removed = list_1637 - list_1684
business_category_to_be_removed
# Out:
# {'hypnosisandhypnotherapy', 'physiotherapist', 'psychotherapists'}

# %%
business_category_to_be_removed = list_1684 - list_1637
len(business_category_to_be_removed)
# Out:
# 49

# %%
set(list_1684 - list_1637)
# Out:
# {'ayesha_curry_food',
#  'ayesha_curry_food_2',
#  'ayesha_curry_food_3',
#  'boxing_day',
#  'conference_attendee',
#  'custom',
#  'dan_nonprofit',
#  'dan_nonprofit_2',
#  'dan_nonprofit_3',
#  'dentallab',
#  'elohim_music',
#  'elohim_music_2',
#  'elohim_music_3',
#  'eventphotography',
#  'familylawattorney',
#  'farms',
#  'fathers_day',
#  'faxservice',
#  'generic',
#  'guns_and_ammo',
#  'gymnastics',
#  'hearingaidproviders',
#  'hearingaidrepair',
#  'lightning',
#  'lyn_fashion',
#  'lyn_fashion_2',
#  'lyn_fashion_3',
#  'meatpacker',
#  'na',
#  'nine_pin_bowling',
#  'other',
#  'paloma_florist',
#  'paloma_florist_2',
#  'paloma_florist_3',
#  'personal_fashion',
#  'personal_fooddrink',
#  'personal_pets',
#  'personal_photography',
#  'photographers',
#  'pianoinstructor',
#  'restaurant',
#  'taxreturnpreparationfiling',
#  'tobaccoshops',
#  'travel',
#  'trussmanufacturer',
#  'tyson_manufacturing',
#  'tyson_manufacturing_2',
#  'tyson_manufacturing_3',
# ...

# %%
# Query 2

# with temp_data as
# (
# select
#     B.domain_name,
#     A.website_id,
#     A.business_category,
#     B.gd_domain
# from gmode.gocentral_websitebuilder_session A
# join gmode.gocentral_website_history B
# on A.website_id = B.website_id
# where A.business_category not like '%_other_%'
#       and B.gd_domain = 0
# )
# select 
#     domain_name, 
#     business_category
# from temp_data
# where business_category not in ('',
#  'ayesha_curry_food',
#  'ayesha_curry_food_2',
#  'ayesha_curry_food_3',
#  'boxing_day',
#  'conference_attendee',
#  'custom',
#  'dan_nonprofit',
#  'dan_nonprofit_2',
#  'dan_nonprofit_3',
#  'dentallab',
#  'elohim_music',
#  'elohim_music_2',
#  'elohim_music_3',
#  'eventphotography',
#  'familylawattorney',
#  'farms',
#  'fathers_day',
#  'faxservice',
#  'generic',
#  'guns_and_ammo',
#  'gymnastics',
#  'hearingaidproviders',
#  'hearingaidrepair',
#  'lightning',
#  'lyn_fashion',
#  'lyn_fashion_2',
#  'lyn_fashion_3',
#  'meatpacker',
#  'na',
#  'nine_pin_bowling',
#  'other',
#  'paloma_florist',
#  'paloma_florist_2',
#  'paloma_florist_3',
#  'personal_fashion',
#  'personal_fooddrink',
#  'personal_pets',
#  'personal_photography',
#  'photographers',
#  'pianoinstructor',
#  'restaurant',
#  'taxreturnpreparationfiling',
#  'tobaccoshops',
#  'travel',
#  'trussmanufacturer',
#  'tyson_manufacturing',
#  'tyson_manufacturing_2',
#  'tyson_manufacturing_3',
#  'visiting_card')
#  and domain_name is not null;

# %%
df_query2 = pd.read_csv("query2_results.csv", header=0)
df_query2.head()
# Out:
#                         domain_name business_category
# 0                 monarchdrives.com             limos
# 1   eastcoastcraftspiritsawards.com     beer_and_wine
# 2                 tiedyetoronto.com          clothing
# 3             northgatepomskies.com       petbreeders
# 4  akronpersonalinjuryattorneys.com      online_store

# %%
df_query2.shape
# Out:
# (6657530, 2)

# %%
df_query2['business_category'].value_counts()
# Out:
# business_category
# coming_soon                                         241063
# clothing                                            170783
# online_store                                        141797
# consultantsgeneralservices                          123638
# blog                                                116076
# itservices                                          101359
# nonprofit                                           100516
# realestate                                           93449
# marketingconsultants                                 70032
# cosmetics                                            64936
# ecommerceservice                                     61344
# realestateagents                                     59986
# music                                                57010
# photography                                          56333
# personal_art                                         55706
# businessconsultants                                  51406
# ...

# %%
# Query 3

# with temp_data as
# (
# select
#     B.domain_name,
#     A.website_id,
#     A.business_category,
#     B.gd_domain
# from gmode.gocentral_websitebuilder_session A
# join gmode.gocentral_website_history B
# on A.website_id = B.website_id
# where A.business_category not like '%_other_%'
#       and B.gd_domain = 0
# )
# select 
#     A.domain_name, 
#     A.business_category
# from temp_data A,
#      (select business_category, count(domain_name) as total_counts from temp_data group by 1) B
# where 
# A.business_category = B.business_category
# and B.total_counts >= 1000
# and A.business_category not in ('',
#  'ayesha_curry_food',
#  'ayesha_curry_food_2',
#  'ayesha_curry_food_3',
#  'boxing_day',
#  'conference_attendee',
#  'custom',
#  'dan_nonprofit',
#  'dan_nonprofit_2',
#  'dan_nonprofit_3',
#  'dentallab',
#  'elohim_music',
#  'elohim_music_2',
#  'elohim_music_3',
#  'eventphotography',
#  'familylawattorney',
#  'farms',
#  'fathers_day',
#  'faxservice',
#  'generic',
#  'guns_and_ammo',
#  'gymnastics',
#  'hearingaidproviders',
#  'hearingaidrepair',
#  'lightning',
#  'lyn_fashion',
#  'lyn_fashion_2',
#  'lyn_fashion_3',
#  'meatpacker',
#  'na',
#  'nine_pin_bowling',
#  'other',
#  'paloma_florist',
#  'paloma_florist_2',
#  'paloma_florist_3',
#  'personal_fashion',
#  'personal_fooddrink',
#  'personal_pets',
#  'personal_photography',
#  'photographers',
#  'pianoinstructor',
#  'restaurant',
#  'taxreturnpreparationfiling',
#  'tobaccoshops',
#  'travel',
#  'trussmanufacturer',
#  'tyson_manufacturing',
#  'tyson_manufacturing_2',
#  'tyson_manufacturing_3',
#  'visiting_card')
#  and domain_name is not null

# %%
df_query3 = pd.read_csv("query3_results.csv", header=0)
df_query3.head()
# Out:
#                        domain_name      business_category
# 0                   armagosthr.com  humanresourceservices
# 1  heartandhandsmassageandclay.com        massage_therapy
# 2               physicsgurucool.in              education
# 3                pequisacolors.com             paintstore
# 4                    fletch-co.com         craft_business

# %%
df_query3.shape
# Out:
# (6331244, 2)

# %%
df_query3['business_category'].value_counts()
# Out:
# business_category
# coming_soon                                         241063
# clothing                                            170783
# online_store                                        141797
# consultantsgeneralservices                          123638
# blog                                                116076
# itservices                                          101359
# nonprofit                                           100516
# realestate                                           93449
# marketingconsultants                                 70032
# cosmetics                                            64936
# ecommerceservice                                     61344
# realestateagents                                     59986
# music                                                57010
# photography                                          56333
# personal_art                                         55706
# businessconsultants                                  51406
# ...

# %%
len(set(df_query3['business_category'].values))
# Out:
# 825
